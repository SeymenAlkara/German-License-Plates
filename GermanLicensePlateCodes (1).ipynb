# %%
https://www.customeuropeanplates.com/german-license-plate-codes
https://www.britannica.com/topic/list-of-cities-and-towns-in-Germany-2038874

what this code shall do is to pick 2 letter codes for german license plates so that never 2 are alike. 26*26=25^2+1+2*25=676 should be enough
but most cities start with Fr- and Sch- and whatever so
the code must proceed to the 2nd letter and 3rd letter and so on

but this is simplistic. we could just jump to the 3rd letter and make a 2-letter code: letter1 & letter3 for example to keep the code shorter

# %%
stateList = ["Baden-Württemberg", "Bavaria", "Berlin", "Brandenburg", "Bremen", "Hamburg", "Hessen", "Lower Saxony", "Mecklenburg-West Pomerania", "North Rhine-Westphalia", "Rhineland-Palatinate", "Saarland", "Saxony", "Saxony-Anhalt", "Schleswig-Holstein"]
# what if I created the codes step by step checking if they are in the dict? Say Schwabisch 1st put S then Sc then Sch always increase 1 letter
# but the list can also benefit from the 1st city increasing number of letters
cityList = [ "Aalen", "Bad Mergentheim", "Baden-Baden", "Bruchsal", "Esslingen", "Freiburg im Breisgau", "Freudenstadt", "Friedrichshafen", "Göppingen", "Hechingen", "Heidelberg",\
"Heilbronn", "Karlsruhe", "Konstanz", "Ludwigsburg", "Mannheim", "Offenburg", "Pforzheim", "Ravensburg", "Reutlingen","Schwäbisch Gmünd","Schwäbisch Hall","Stuttgart","Tübingen","Ulm"\
,"Amberg","Ansbach","Aschaffenburg","Augsburg","Bad Reichenhall","Bamberg","Bayreuth","Berchtesgaden","Coburg","Dachau","Deggendorf","Dinkelsbühl","Donauwörth","Erlangen","Freising",\
"Fürth","Füssen","Garmisch-Partenkirchen","Ingolstadt","Kempten","Landshut","Lindau","Memmingen","Mittenwald","Munich","Nördlingen","Nürnberg","Passau","Regensburg"\
,"Rothenburg ob der Tauber","Würzburg","Berlin","Charlottenburg (district)" ,"Spandau (area)","Tempelhof (area)","Tiergarten (area)","Brandenburg","Cottbus","Eberswalde",\
"Frankfurt an der Oder","Potsdam","Schwedt","Bremen","Bremerhaven" ,"Hamburg","Altona (district)","Bad Homburg","Darmstadt","Frankfurt am Main","Fulda","Giessen","Hanau","Kassel",\
"Lorsch","Marburg","Offenbach","Rüdesheim","Wiesbaden","Bad Gandersheim" ,"Bad Harzburg","Braunschweig","Celle","Cuxhaven" ,"Delmenhorst","Emden","Goslar","Göttingen" ,"Hameln",\
"Hannover","Helmstedt","Hildesheim","Lüneburg","Oldenburg","Osnabrück","Salzgitter","Stade","Wilhelmshaven","Wolfsburg","Greifswald","Güstrow","Neubrandenburg","Peenemünde","Rostock",\
"Schwerin","Stralsund","Wismar","Aachen","Arnsberg","Bad Godesberg" ,"Bergisch Gladbach","Bielefeld","Bocholt","Bochum","Bonn","Bottrop","Brühl","Castrop-Rauxel","Cologne","Detmold",\
"Dorsten","Dortmund","Duisburg","Düren","Düsseldorf","Essen","Gelsenkirchen","Gladbeck","Gütersloh","Hagen","Hamm","Herne","Hürth","Iserlohn","Jülich","Kleve","Königswinter","Krefeld",\
"Leverkusen","Lüdenscheid","Lünen","Marl","Minden","Moers","Mönchengladbach","Mülheim an der Ruhr","Münster","Neuss","Paderborn","Recklinghausen","Remscheid","Rheine","Siegen","Soest",\
"Solingen","Wesel","Witten","Wuppertal","Bad Kreuznach","Bingen","Boppard","Frankenthal" ,"Kaiserslautern","Koblenz", "Landau","Ludwigshafen","Mainz","Neustadt an der Weinstrasse",\
"Speyer","Trier","Worms","Saarland","Homburg","Reinheim","Saarbrücken","Saarlouis","Saxony","Altenburg","Annaberg-Buchholz","Bautzen","Chemnitz","Dresden","Freiberg","Görlitz",\
"Hoyerswerda","Leipzig","Meissen","Torgau","Zittau","Zwickau","Bernburg","Dessau","Eisleben","Halberstadt","Halle","Köthen","Merseburg","Naumburg","Quedlinburg","Stendal",\
"Wernigerode","Wittenberg","Büsum","Eutin","Flensburg" ,"Glückstadt","Kiel","Lübeck","Rendsburg","Schleswig","Thuringia","Arnstadt","Eisenach","Erfurt","Gera","Gotha","Jena",\
"Meiningen","Mühlhausen","Nordhausen", "Suhl","Weimar"]

licensePlateCodes3 = {}
for city in cityList:
  if city[0] not in licensePlateCodes3:
    licensePlateCodes3[city[:1]]=city
  else:
    if city[0:2] not in licensePlateCodes3:
      licensePlateCodes3[city[:2]]=city
    else:
      if city[0:3] not in licensePlateCodes3:
        licensePlateCodes3[city[:3]]=city

licensePlateCodes3
# Out:
# {'A': 'Aalen',
#  'B': 'Bad Mergentheim',
#  'Ba': 'Baden-Baden',
#  'Br': 'Bruchsal',
#  'E': 'Esslingen',
#  'F': 'Freiburg im Breisgau',
#  'Fr': 'Freudenstadt',
#  'Fri': 'Friedrichshafen',
#  'G': 'Göppingen',
#  'H': 'Hechingen',
#  'He': 'Heidelberg',
#  'Hei': 'Heilbronn',
#  'K': 'Karlsruhe',
#  'Ko': 'Konstanz',
#  'L': 'Ludwigsburg',
#  'M': 'Mannheim',
#  'O': 'Offenburg',
#  'P': 'Pforzheim',
#  'R': 'Ravensburg',
#  'Re': 'Reutlingen',
#  'S': 'Schwäbisch Gmünd',
#  'Sc': 'Schwäbisch Hall',
#  'St': 'Stuttgart',
#  'T': 'Tübingen',
#  'U': 'Ulm',
#  'Am': 'Amberg',
#  'An': 'Ansbach',
#  'As': 'Aschaffenburg',
#  'Au': 'Augsburg',
#  'Bad': 'Bad Reichenhall',
#  'Bam': 'Bamberg',
#  'Bay': 'Bayreuth',
#  'Be': 'Berchtesgaden',
#  'C': 'Coburg',
#  'D': 'Dachau',
#  'De': 'Deggendorf',
#  'Di': 'Dinkelsbühl',
#  'Do': 'Donauwörth',
#  'Er': 'Erlangen',
#  'Fre': 'Freising',
#  'Fü': 'Fürth',
#  'Füs': 'Füssen',
#  'Ga': 'Garmisch-Partenkirchen',
#  'I': 'Ingolstadt',
# ...

# %%
myKeys = list(licensePlateCodes3.keys())
myKeys.sort()
sorted_dict2 = {i: licensePlateCodes3[i] for i in myKeys}
sorted_dict2
# Out:
# {'A': 'Aalen',
#  'Aa': 'Aachen',
#  'Al': 'Altona (district)',
#  'Alt': 'Altenburg',
#  'Am': 'Amberg',
#  'An': 'Ansbach',
#  'Ann': 'Annaberg-Buchholz',
#  'Ar': 'Arnsberg',
#  'Arn': 'Arnstadt',
#  'As': 'Aschaffenburg',
#  'Au': 'Augsburg',
#  'B': 'Bad Mergentheim',
#  'Ba': 'Baden-Baden',
#  'Bad': 'Bad Reichenhall',
#  'Bam': 'Bamberg',
#  'Bau': 'Bautzen',
#  'Bay': 'Bayreuth',
#  'Be': 'Berchtesgaden',
#  'Ber': 'Berlin',
#  'Bi': 'Bielefeld',
#  'Bin': 'Bingen',
#  'Bo': 'Bocholt',
#  'Boc': 'Bochum',
#  'Bon': 'Bonn',
#  'Bop': 'Boppard',
#  'Bot': 'Bottrop',
#  'Br': 'Bruchsal',
#  'Bra': 'Brandenburg',
#  'Bre': 'Bremen',
#  'Brü': 'Brühl',
#  'Bü': 'Büsum',
#  'C': 'Coburg',
#  'Ca': 'Castrop-Rauxel',
#  'Ce': 'Celle',
#  'Ch': 'Charlottenburg (district)',
#  'Che': 'Chemnitz',
#  'Co': 'Cottbus',
#  'Col': 'Cologne',
#  'Cu': 'Cuxhaven',
#  'D': 'Dachau',
#  'Da': 'Darmstadt',
#  'De': 'Deggendorf',
#  'Del': 'Delmenhorst',
#  'Des': 'Dessau',
#  'Det': 'Detmold',
# ...

# %%
myKeys = list(licensePlateCodes2.keys())
myKeys.sort()
sorted_dict = {i: licensePlateCodes2[i] for i in myKeys}
sorted_dict
# Out:
# {'A': 'Aalen',
#  'Aa': 'Aachen',
#  'Al': 'Altona (district)',
#  'Alte': 'Altenburg',
#  'Am': 'Amberg',
#  'An': 'Ansbach',
#  'Anna': 'Annaberg-Buchholz',
#  'Ar': 'Arnsberg',
#  'Arns': 'Arnstadt',
#  'As': 'Aschaffenburg',
#  'Au': 'Augsburg',
#  'B': 'Bad Mergentheim',
#  'Ba': 'Baden-Baden',
#  'Bad ': 'Bad Kreuznach',
#  'Bamb': 'Bamberg',
#  'Baut': 'Bautzen',
#  'Bayr': 'Bayreuth',
#  'Be': 'Berchtesgaden',
#  'Berg': 'Bergisch Gladbach',
#  'Berl': 'Berlin',
#  'Bern': 'Bernburg',
#  'Bi': 'Bielefeld',
#  'Bing': 'Bingen',
#  'Bo': 'Bocholt',
#  'Boch': 'Bochum',
#  'Bonn': 'Bonn',
#  'Bopp': 'Boppard',
#  'Bott': 'Bottrop',
#  'Br': 'Bruchsal',
#  'Bran': 'Brandenburg',
#  'Brau': 'Braunschweig',
#  'Brem': 'Bremerhaven',
#  'Brüh': 'Brühl',
#  'Bü': 'Büsum',
#  'C': 'Coburg',
#  'Ca': 'Castrop-Rauxel',
#  'Ce': 'Celle',
#  'Ch': 'Charlottenburg (district)',
#  'Chem': 'Chemnitz',
#  'Co': 'Cottbus',
#  'Colo': 'Cologne',
#  'Cu': 'Cuxhaven',
#  'D': 'Dachau',
# ...

# %%
licensePlateCodes4 = {}
for city in cityList:
  if city[0] not in licensePlateCodes4:
    licensePlateCodes4[city[:1]]=city
  else:
    if city[0:2] not in licensePlateCodes4:
      licensePlateCodes4[city[:2]]=city
    else:
      if city[0:3] not in licensePlateCodes4:
        licensePlateCodes4[city[:3]]=city
      else:
        if city[0:4] not in licensePlateCodes4:
          licensePlateCodes4[city[:4]]=city

licensePlateCodes4
# Out:
# {'A': 'Aalen',
#  'B': 'Bad Mergentheim',
#  'Ba': 'Baden-Baden',
#  'Br': 'Bruchsal',
#  'E': 'Esslingen',
#  'F': 'Freiburg im Breisgau',
#  'Fr': 'Freudenstadt',
#  'Fri': 'Friedrichshafen',
#  'G': 'Göppingen',
#  'H': 'Hechingen',
#  'He': 'Heidelberg',
#  'Hei': 'Heilbronn',
#  'K': 'Karlsruhe',
#  'Ko': 'Konstanz',
#  'L': 'Ludwigsburg',
#  'M': 'Mannheim',
#  'O': 'Offenburg',
#  'P': 'Pforzheim',
#  'R': 'Ravensburg',
#  'Re': 'Reutlingen',
#  'S': 'Schwäbisch Gmünd',
#  'Sc': 'Schwäbisch Hall',
#  'St': 'Stuttgart',
#  'T': 'Tübingen',
#  'U': 'Ulm',
#  'Am': 'Amberg',
#  'An': 'Ansbach',
#  'As': 'Aschaffenburg',
#  'Au': 'Augsburg',
#  'Bad': 'Bad Reichenhall',
#  'Bam': 'Bamberg',
#  'Bay': 'Bayreuth',
#  'Be': 'Berchtesgaden',
#  'C': 'Coburg',
#  'D': 'Dachau',
#  'De': 'Deggendorf',
#  'Di': 'Dinkelsbühl',
#  'Do': 'Donauwörth',
#  'Er': 'Erlangen',
#  'Fre': 'Freising',
#  'Fü': 'Fürth',
#  'Füs': 'Füssen',
#  'Ga': 'Garmisch-Partenkirchen',
#  'I': 'Ingolstadt',
# ...

# %%
myKeys = list(licensePlateCodes4.keys())
myKeys.sort()
sorted_dict3 = {i: licensePlateCodes4[i] for i in myKeys}
sorted_dict3
# Out:
# {'A': 'Aalen',
#  'Aa': 'Aachen',
#  'Al': 'Altona (district)',
#  'Alt': 'Altenburg',
#  'Am': 'Amberg',
#  'An': 'Ansbach',
#  'Ann': 'Annaberg-Buchholz',
#  'Ar': 'Arnsberg',
#  'Arn': 'Arnstadt',
#  'As': 'Aschaffenburg',
#  'Au': 'Augsburg',
#  'B': 'Bad Mergentheim',
#  'Ba': 'Baden-Baden',
#  'Bad': 'Bad Reichenhall',
#  'Bad ': 'Bad Homburg',
#  'Bam': 'Bamberg',
#  'Bau': 'Bautzen',
#  'Bay': 'Bayreuth',
#  'Be': 'Berchtesgaden',
#  'Ber': 'Berlin',
#  'Berg': 'Bergisch Gladbach',
#  'Bern': 'Bernburg',
#  'Bi': 'Bielefeld',
#  'Bin': 'Bingen',
#  'Bo': 'Bocholt',
#  'Boc': 'Bochum',
#  'Bon': 'Bonn',
#  'Bop': 'Boppard',
#  'Bot': 'Bottrop',
#  'Br': 'Bruchsal',
#  'Bra': 'Brandenburg',
#  'Brau': 'Braunschweig',
#  'Bre': 'Bremen',
#  'Brem': 'Bremerhaven',
#  'Brü': 'Brühl',
#  'Bü': 'Büsum',
#  'C': 'Coburg',
#  'Ca': 'Castrop-Rauxel',
#  'Ce': 'Celle',
#  'Ch': 'Charlottenburg (district)',
#  'Che': 'Chemnitz',
#  'Co': 'Cottbus',
#  'Col': 'Cologne',
# ...

# %%
city = "Taşşakow"
print(city[:2])
print(city[:3])
city[:4]
# Out:
# Ta
# Taş
# 'Taşş'

# %%
print(len(cityList))
len(licensePlateCodes)
# Out:
# 226
# 124

# %%
print(len(cityList))
len(licensePlateCodes2)
# Out:
# 226
# 212

# %%
print(len(cityList))
len(licensePlateCodes3)
# Out:
# 226
# 203

# %%
print(len(cityList))
len(licensePlateCodes4)
# Out:
# 226
# 220

# %%
reverseDict = {val: key for key, val in licensePlateCodes4.items()}
reverseDict
# Out:
# {'Aalen': 'A',
#  'Bad Mergentheim': 'B',
#  'Baden-Baden': 'Ba',
#  'Bruchsal': 'Br',
#  'Esslingen': 'E',
#  'Freiburg im Breisgau': 'F',
#  'Freudenstadt': 'Fr',
#  'Friedrichshafen': 'Fri',
#  'Göppingen': 'G',
#  'Hechingen': 'H',
#  'Heidelberg': 'He',
#  'Heilbronn': 'Hei',
#  'Karlsruhe': 'K',
#  'Konstanz': 'Ko',
#  'Ludwigsburg': 'L',
#  'Mannheim': 'M',
#  'Offenburg': 'O',
#  'Pforzheim': 'P',
#  'Ravensburg': 'R',
#  'Reutlingen': 'Re',
#  'Schwäbisch Gmünd': 'S',
#  'Schwäbisch Hall': 'Sc',
#  'Stuttgart': 'St',
#  'Tübingen': 'T',
#  'Ulm': 'U',
#  'Amberg': 'Am',
#  'Ansbach': 'An',
#  'Aschaffenburg': 'As',
#  'Augsburg': 'Au',
#  'Bad Reichenhall': 'Bad',
#  'Bamberg': 'Bam',
#  'Bayreuth': 'Bay',
#  'Berchtesgaden': 'Be',
#  'Coburg': 'C',
#  'Dachau': 'D',
#  'Deggendorf': 'De',
#  'Dinkelsbühl': 'Di',
#  'Donauwörth': 'Do',
#  'Erlangen': 'Er',
#  'Freising': 'Fre',
#  'Fürth': 'Fü',
#  'Füssen': 'Füs',
#  'Garmisch-Partenkirchen': 'Ga',
#  'Ingolstadt': 'I',
# ...

# %%
myKeys = list(reverseDict.keys())
myKeys.sort()
reversed_dict = {i: reverseDict[i] for i in myKeys}
reversed_dict
# Out:
# {'Aachen': 'Aa',
#  'Aalen': 'A',
#  'Altenburg': 'Alt',
#  'Altona (district)': 'Al',
#  'Amberg': 'Am',
#  'Annaberg-Buchholz': 'Ann',
#  'Ansbach': 'An',
#  'Arnsberg': 'Ar',
#  'Arnstadt': 'Arn',
#  'Aschaffenburg': 'As',
#  'Augsburg': 'Au',
#  'Bad Homburg': 'Bad ',
#  'Bad Mergentheim': 'B',
#  'Bad Reichenhall': 'Bad',
#  'Baden-Baden': 'Ba',
#  'Bamberg': 'Bam',
#  'Bautzen': 'Bau',
#  'Bayreuth': 'Bay',
#  'Berchtesgaden': 'Be',
#  'Bergisch Gladbach': 'Berg',
#  'Berlin': 'Ber',
#  'Bernburg': 'Bern',
#  'Bielefeld': 'Bi',
#  'Bingen': 'Bin',
#  'Bocholt': 'Bo',
#  'Bochum': 'Boc',
#  'Bonn': 'Bon',
#  'Boppard': 'Bop',
#  'Bottrop': 'Bot',
#  'Brandenburg': 'Bra',
#  'Braunschweig': 'Brau',
#  'Bremen': 'Bre',
#  'Bremerhaven': 'Brem',
#  'Bruchsal': 'Br',
#  'Brühl': 'Brü',
#  'Büsum': 'Bü',
#  'Castrop-Rauxel': 'Ca',
#  'Celle': 'Ce',
#  'Charlottenburg (district)': 'Ch',
#  'Chemnitz': 'Che',
#  'Coburg': 'C',
#  'Cologne': 'Col',
#  'Cottbus': 'Co',
# ...

# %%
def lookUpCity(city, dct): #licensePlateCodes
  reverseDict = {val: key for key, val in dct.items()}
  return reverseDict[city]

# %%
ıhdines = {"M": "Munich", "T": "Teisnach"}
if "M" in ıhdines:
  print(ıhdines["M"])
lookUpCity("Teisnach", ıhdines)
# Out:
# Munich
# 'T'
